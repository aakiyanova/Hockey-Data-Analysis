# %% [markdown]
# #### Gordie Howe Stats and Awards

# %%
# imports
import pandas as pd
import numpy as np
import zipfile
import os

# %%
# unzip the folder
with zipfile.ZipFile('data/HockeyData.zip', 'r') as zip_ref:
    zip_ref.extractall('data')

# %% [markdown]
# **Hall of Fame dataframe**

# %%
# read hall of fame csv file
hof = pd.read_csv('data/HOF.csv')

# %%
# check if Gordie Howe has been admitted to the hall of fame 
hof.loc[hof['name']=='Gordie Howe']
# Out:
#      year      hofID         name category
# 183  1972  howego01h  Gordie Howe   Player

# %% [markdown]
# **Player awards**

# %%
# read awards csv file
awards = pd.read_csv('data/AwardsPlayers.csv')

# %%
# observe the awards given to Howe
howe_awards = awards.loc[awards['playerID'] == 'howego01'] 
howe_awards.head()
# Out:
#      playerID                 award  year lgID note  pos
# 346  howego01  Second Team All-Star  1948  NHL  NaN   RW
# 361  howego01  Second Team All-Star  1949  NHL  NaN   RW
# 368  howego01              Art Ross  1950  NHL  NaN  NaN
# 370  howego01   First Team All-Star  1950  NHL  NaN   RW
# 386  howego01              Art Ross  1951  NHL  NaN  NaN

# %% [markdown]
# **Master dataframe**

# %%
# read master csv file
master = pd.read_csv('data/Master.csv')

# %%
# see Howe's stats
howe_stats = master.loc[master['playerID'] == 'howego01']
howe_stats
# Out:
#       playerID coachID      hofID firstName lastName nameNote nameGiven  \
# 3044  howego01     NaN  howego01h    Gordie     Howe      NaN    Gordon
#
#         nameNick  height  weight  ... birthDay birthCountry  birthState  \
# 3044  Mr. Hockey    72.0   205.0  ...     31.0       Canada          SK
#
#      birthCity  deathYear  deathMon  deathDay  deathCountry deathState  \
# 3044    Floral        NaN       NaN       NaN           NaN        NaN
#
#       deathCity
# 3044        NaN
#
# [1 rows x 31 columns]

# %% [markdown]
# **Scoring**

# %%
# read scoring csv file
scoring = pd.read_csv('data/Scoring.csv')

# %%
scoring.columns
# Out:
# Index(['playerID', 'year', 'stint', 'tmID', 'lgID', 'pos', 'GP', 'G', 'A',
#        'Pts', 'PIM', '+/-', 'PPG', 'PPA', 'SHG', 'SHA', 'GWG', 'GTG', 'SOG',
#        'PostGP', 'PostG', 'PostA', 'PostPts', 'PostPIM', 'Post+/-', 'PostPPG',
#        'PostPPA', 'PostSHG', 'PostSHA', 'PostGWG', 'PostSOG'],
#       dtype='object')

# %%
# observe stats scoring stats related to the player
howe_score = scoring.loc[scoring['playerID'] == 'howego01']
howe_score.head()
# Out:
#        playerID  year  stint tmID lgID pos    GP     G     A   Pts  ...  \
# 17877  howego01  1946      1  DET  NHL   R  58.0   7.0  15.0  22.0  ...
# 17878  howego01  1947      1  DET  NHL   R  60.0  16.0  28.0  44.0  ...
# 17879  howego01  1948      1  DET  NHL   R  40.0  12.0  25.0  37.0  ...
# 17880  howego01  1949      1  DET  NHL   R  70.0  35.0  33.0  68.0  ...
# 17881  howego01  1950      1  DET  NHL   R  70.0  43.0  43.0  86.0  ...
#
#        PostA  PostPts  PostPIM  Post+/-  PostPPG  PostPPA  PostSHG  PostSHA  \
# 17877    0.0      0.0     18.0      NaN      NaN      NaN      NaN      NaN
# 17878    1.0      2.0     11.0      NaN      NaN      NaN      NaN      NaN
# 17879    3.0     11.0     19.0      NaN      NaN      NaN      NaN      NaN
# 17880    0.0      0.0      7.0      NaN      NaN      NaN      NaN      NaN
# 17881    3.0      7.0      4.0      NaN      NaN      NaN      NaN      NaN
#
#        PostGWG  PostSOG
# 17877      NaN      NaN
# 17878      NaN      NaN
# ...

# %% [markdown]
# **Shootouts**

# %%
# read scoring shootouts csv file
shoot = pd.read_csv('data/ScoringShootout.csv')

# %%
# observe shots / goals ratio
howe_shoot = shoot.loc[shoot['playerID'] == 'howego01']
howe_shoot.head()
# Out:
# Empty DataFrame
# Columns: [playerID, year, stint, tmID, S, G, GDG]
# Index: []

# %% [markdown]
# #### Detroit Red Wings Stats and Awards

# %% [markdown]
# **Series Wins & Losses**

# %%
# read series post csv file
series = pd.read_csv('data/SeriesPost.csv')

# %%
# see Red Wings' wins
det_wins = series.loc[series['tmIDWinner'] == 'DET']
det_wins.head()
# Out:
#     year round series tmIDWinner lgIDWinner tmIDLoser lgIDLoser  W  L  T  \
# 77  1932    QF      B        DET        NHL       MTM       NHL  2  0  0
# 81  1933    SF      A        DET        NHL       TOR       NHL  3  2  0
# 91  1935    SF      A        DET        NHL       MTM       NHL  3  0  0
# 95  1935   SCF      E        DET        NHL       TOR       NHL  3  1  0
# 96  1936    SF      A        DET        NHL       MTL       NHL  3  2  0
#
#     GoalsWinner  GoalsLoser note
# 77            5           2   TG
# 81           11          12  NaN
# 91            6           1  NaN
# 95           18          11  NaN
# 96           13           8  NaN

# %%
# see Red Wings' losses
det_losses = series.loc[series['tmIDLoser'] == 'DET']
det_losses.head()
# Out:
#      year round series tmIDWinner lgIDWinner tmIDLoser lgIDLoser  W  L  T  \
# 79   1932    SF      D        NYR        NHL       DET       NHL  2  0  0
# 85   1933   SCF      E        CHI        NHL       DET       NHL  3  1  0
# 109  1938    SF      D        TOR        NHL       DET       NHL  2  1  0
# 114  1939    SF      D        TOR        NHL       DET       NHL  2  0  0
# 120  1940   SCF      E        BOS        NHL       DET       NHL  4  0  0
#
#      GoalsWinner  GoalsLoser note
# 79             6           3   TG
# 85             9           7  NaN
# 109           10           8  NaN
# 114            5           2  NaN
# 120           12           6  NaN

# %% [markdown]
# **Team vs Team Stats**

# %%
# read team vs team csv file
team_vs_team = pd.read_csv('data/TeamVsTeam.csv')

# %%
# explore Red Wings' opponents
det_team_stats = team_vs_team.loc[team_vs_team['tmID'] == 'DET']
det_team_stats.head()
# Out:
#       year lgID tmID oppID  W  L    T  OTL
# 1120  1932  NHL  DET   BOS  3  2  1.0  NaN
# 1121  1932  NHL  DET   CHI  5  1  0.0  NaN
# 1122  1932  NHL  DET   MTL  3  2  1.0  NaN
# 1123  1932  NHL  DET   MTM  1  4  1.0  NaN
# 1124  1932  NHL  DET   NYA  3  0  3.0  NaN

# %% [markdown]
# **Team Stats**

# %%
# read teams csv file
teams = pd.read_csv('data/Teams.csv')

# %%
# see Red Wings' stats
det = teams.loc[teams['tmID'] == 'DET']
det.head()
# Out:
#      year lgID tmID franchID confID divID  rank playoff   G   W  ...   GA  \
# 210  1932  NHL  DET      DET    NaN    AM     2      SF  48  25  ...   93
# 219  1933  NHL  DET      DET    NaN    AM     1       F  48  24  ...   98
# 228  1934  NHL  DET      DET    NaN    AM     4     NaN  48  19  ...  114
# 237  1935  NHL  DET      DET    NaN    AM     1      SC  48  24  ...  103
# 245  1936  NHL  DET      DET    NaN    AM     1      SC  48  25  ...  102
#
#                   name    PIM  BenchMinor  PPG  PPC  SHA  PKG PKC  SHF
# 210  Detroit Red Wings  462.0         NaN  NaN  NaN  NaN  NaN NaN  NaN
# 219  Detroit Red Wings  368.0         NaN  NaN  NaN  NaN  NaN NaN  NaN
# 228  Detroit Red Wings  326.0         NaN  NaN  NaN  NaN  NaN NaN  NaN
# 237  Detroit Red Wings  376.0         NaN  NaN  NaN  NaN  NaN NaN  NaN
# 245  Detroit Red Wings  244.0         NaN  NaN  NaN  NaN  NaN NaN  NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# **Teams Half Season**

# %%
# read teams half season csv file
teamshalf = pd.read_csv('data/TeamsHalf.csv')

# %%
# look at Red Wings' performance 
det_half = teamshalf.loc[teamshalf['tmID'] == 'DET']
det_half.head()
# Out:
# Empty DataFrame
# Columns: [year, lgID, tmID, half, rank, G, W, L, T, GF, GA]
# Index: []

# %% [markdown]
# **Teams Post Seasons**

# %%
# read Teams post season csv file
teamspost = pd.read_csv('data/TeamsPost.csv')

# %%
# see Red Wings' stats
det_post = teamspost.loc[teamspost['tmID'] == 'DET']
det_post.head()
# Out:
#      year lgID tmID   G  W  L  T  GF  GA   PIM  BenchMinor  PPG  PPC  SHA  \
# 87   1932  NHL  DET   4  2  2  0   8   8  41.0         NaN  NaN  NaN  NaN
# 93   1933  NHL  DET   9  4  5  0  18  21  65.0         NaN  NaN  NaN  NaN
# 106  1935  NHL  DET   7  6  1  0  24  12  36.0         NaN  NaN  NaN  NaN
# 111  1936  NHL  DET  10  6  4  0  22  16  57.0         NaN  NaN  NaN  NaN
# 123  1938  NHL  DET   6  3  3  0  16  15  51.0         NaN  NaN  NaN  NaN
#
#      PKG  PKC  SHF
# 87   NaN  NaN  NaN
# 93   NaN  NaN  NaN
# 106  NaN  NaN  NaN
# 111  NaN  NaN  NaN
# 123  NaN  NaN  NaN

# %% [markdown]
# **Teams Stanley Cup**

# %%
# read teams stanley cup csv file
teamssc = pd.read_csv('data/TeamsSC.csv')

# %%
det_sc = teamssc.loc[teamssc['tmID'] == 'NYI'] # the data is up to 1925 and does not mention the Detroir Red Wings
det_sc.head()
# Out:
# Empty DataFrame
# Columns: [year, lgID, tmID, G, W, L, T, GF, GA, PIM]
# Index: []
